# %% [markdown]
# <h2>Data Analytics- notebook template and instructions</h2>

# %% [markdown]
# <b style="color: red;">NOTE! Only creating seaborn visualizations etc. with your code is not sufficient for a Data Analytics notebook. <u>You also have to explain (either by markdown or code comments) what is interesting in the data, charts or visualizations.</u><br /><br />The reader of this notebook should be quickly able to see the basic information about the data as well the most interesting findings in your analytics.</b>
#
# If it helps you to decide what is important content in this notebook: <b>imagine this data analytics -notebook was going to be given to a customer oin your company. If you wonder "should I write this down", think about if the customer would be interested in that information :)</b>

# %% [markdown]
# <h4><b>Dataset name / short description:</b></h4>

# %% [markdown]
# Write here the name of your dataset (or datasets, if you use multiple datasets for your analysis) and write a short description of the data in each of the datasets. For example "house price data in Chicago, US".
#
# Note: using multiple datasets only refers to using multiple datasets about the same subject (for example, you could have one dataset about European markets and another about US markets). <b>If you're making completely separate data analysis cases, where the datasets have nothing in common, just create another Data Analytics notebook altogether. </b>
#
# You are allowed to return as many Data Analytics notebooks during this course as you want, each are rewarded for points (often easiest way to get to highest grades).

# %% [markdown]
# <h4><b>Data source (url):</b></h4>

# %% [markdown]
# Where is the original data located (kaggle.com, or something else?). Place also the original URL (or all URLs, if using many)

# %% [markdown]
# <h4><b>Data format:</b></h4>

# %% [markdown]
# What was the original data format: csv, json, webscraping or something else? <br /><br />Anything out of the ordinary that any other specialist should know? (this is not always needed. For example, if the data format is somehow not in the default format. Most common case: csv-file, where the separator is not comma, but semi-colon instead.)

# %% [markdown]
# <h4><b>Data description, features and limitations:</b></h4>

# %% [markdown]
# Explain the main features and columns of the data, and are there any limitations? Typically the limitations are having only certain time period or certain countries/areas, only a small number of data etc.
# <br /><br />
# <b>Optional:</b> Value ranges are also a nice information to have, for example: house prices, typical values 100k$ - 7.5M$
# <br /><br />
# <b>Note:</b> If your data consists of multiple files and you combine them, describe how they were combined in this part also (just on the general level).

# %% [markdown]
# <h3><b>Code: importing modules, custom functions and loading the data</b></h3>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Remove scientific notation
pd.options.display.float_format = '{:.0f}'.format

# %%
# %load_ext numpy_html
# Out:
# The numpy_html extension is already loaded. To reload it, use:
#   %reload_ext numpy_html

# %%
# %%html
# <style>
# table {margin-top: 16pt;}
# td {font-family: Arial, Helvetica, sans-serif !important; font-weight: 600; white-space: normal !important;}
# tr:nth-child(even) {background: #b0d9eb !important; color: black}
# tr:nth-child(odd) {background: #8fb1bf !important; color: black}
# </style>
# Out:
# <style>
# table {margin-top: 16pt;}
# td {font-family: Arial, Helvetica, sans-serif !important; font-weight: 600; white-space: normal !important;}
# tr:nth-child(even) {background: #b0d9eb !important; color: black}
# tr:nth-child(odd) {background: #8fb1bf !important; color: black}
# </style>

# %% [markdown]
# <h3><b>Code: Data clean-up procedure</b></h3>

# %%
# clean-up your data with code in this part

# IMPORTANT!: provide also markdown/comments of why you decided to do something with your data
# - what columns you dropped out and why?
# - did you create any new helpful columns or computations?
# - did you combine columns?
# - did your filter or modify any column values and why?
# - were there any duplicate rows, and how did you handle them?
# - were there any missing data, and if there was, how did you handle the missing values? 
# -- also explain the reason on how you decided to handle the missing values in a certain way
# + anything else that is related to data pre-processing
motorcycles = pd.read_csv("motorcycle_sales.csv")

# reorder columns
motorcycles = motorcycles[['name', 'year', 'seller_type', 'owner', 'km_driven', 'selling_price', 'ex_showroom_price']]
motorcycles
# Out:
#                                      name  year seller_type      owner  \
# 0               Royal Enfield Classic 350  2019  Individual  1st owner
# 1                               Honda Dio  2017  Individual  1st owner
# 2     Royal Enfield Classic Gunmetal Grey  2018  Individual  1st owner
# 3       Yamaha Fazer FI V 2.0 [2016-2018]  2015  Individual  1st owner
# 4                   Yamaha SZ [2013-2014]  2011  Individual  2nd owner
# ...                                   ...   ...         ...        ...
# 1056                            Activa 3g  2010  Individual  1st owner
# 1057                     Honda CB twister  2012  Individual  1st owner
# 1058                   Bajaj Discover 125  2013  Individual  2nd owner
# 1059                       Honda CB Shine  2009  Individual  1st owner
# 1060                     Bajaj Pulsar 150  2008  Individual  1st owner
#
#       km_driven  selling_price  ex_showroom_price
# 0           350         175000                NaN
# 1          5650          45000                NaN
# 2         12000         150000             148114
# 3         23000          65000              89643
# 4         21000          20000                NaN
# ...         ...            ...                ...
# 1056     500000          17000              52000
# 1057      33000          16000              51000
# 1058      35000          15000              57000
# 1059      53000          12000              58000
# 1060      92233          10000              75000
#
# [1061 rows x 7 columns]

# %% [markdown]
# <h3><b>Code: Data analysis</b></h3>

# %%
# THIS IS THE MAJOR PART OF THIS ANALYSIS NOTEBOOK

# Add all helpful plots and statistics numbers in this section. 
# Explain also why you selected a certain plot or computation in your analysis, and what you wished to achieve with them. 

# Note: do not add every possible plot and number that there exists, the idea is to be concise.
 
# In other words, only show plots and numbers that show something interesting and mean something.  
# Try to find out interesting correlations, contradictions and potential causations between categories and columns. 
# Is there something that was surprising in the data, or is there something that does or does not make sense?

# if you find something interesting, try also Googling or generative AI to explain what might have happened in the data.
# for example, your analysis could imply house prices fell down dramatically in year 2007. 
# If you Google after this: "house price crisis 2007", you'll find a reason why this might show in the data
# also, based on data it could seem that honey production has decreased even if there are more bee colonies than before
# if you then Google: "honey production has decreased", you might find an explanation

# Support your findings with pandas statistics and seaborn plots. You can also use other plotting libraries if you wish.
# This part of the report can have large amounts of code if the dataset is difficult.

# You can also use quantitative analysis methods (chi-square, t-tests, ANOVA etc.) to support your findings, 
# but these are considered extra tasks/extra points only!

# Tip: you can see many nice tricks for pandas and seaborn in the earlier exercise sets we have done during the
# course. NumPy/pandas/seaborn etc. are just tools, it's okay to use all the tricks these modules have to offer
# in order to find the interesting features of your data!

correlations = motorcycles.corr(numeric_only=True)

# plot correlation matrix
sns.heatmap(correlations, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## The selling price and the year have a strong positive correllation, meaning that newer motorcycles are more expensive. The selling price and the km driven have a negative correllation, meaning that motorcycles that have been ridden for longer distances are cheaper.

# %%
# Function to get make of the motorcycle
def get_make(name):
    if 'Royal Enfield' in name:
        return 'Royal Enfield'
    if 'Honda' in name:
        return 'Honda'
    if 'Yamaha' in name:
        return 'Yamaha'
    if 'Hero' in name:
        return 'Hero'
    if 'Bajaj' in name:
        return 'Bajaj'
    if 'Suzuki' in name:
        return 'Suzuki'
    if 'KTM' in name:
        return 'KTM'
    if 'TVS' in name:
        return 'TVS'
    if 'Jawa' in name:
        return 'Jawa'
    if 'Mahindra' in name:
        return 'Mahindra'
    if 'Aprilia' in name:
        return 'Aprilia'
    if 'Harley-Davidson' in name:
        return 'Harley-Davidson'
    if 'Kawasaki' in name:
        return 'Kawasaki'
    if 'Vespa' in name:
        return 'Vespa'
    if 'UM Renegade' in name:
        return 'UM Renegade'
    if 'Benelli' in name:
        return 'Benelli'
    if 'Activa' in name:
        return 'Activa'
    if 'BMW' in name:
        return 'BMW'
    if 'Hyosung' in name:
        return 'Hyosung'
    if 'Yo Style' in name:
        return 'Yo Style'

# %%
motorcycles['make'] = motorcycles['name'].apply(get_make)
motorcycles['make'].value_counts()
# Out:
# make
# Honda              292
# Bajaj              260
# Hero               144
# Royal Enfield      109
# Yamaha             102
# TVS                 69
# Suzuki              30
# KTM                 24
# Mahindra             6
# Kawasaki             4
# Vespa                4
# UM Renegade          3
# Activa               3
# Jawa                 3
# Harley-Davidson      2
# Aprilia              2
# BMW                  1
# Benelli              1
# Yo Style             1
# Hyosung              1
# Name: count, dtype: int64

# %% [markdown]
# ## Let's drop the makes that have fewer than 10 motorcycles in the list

# %%
makes_to_drop = ['Mahindra', 'Kawasaki', 'Vespa', 'UM Renegade', 'Activa', 'Jawa', 'Harley-Davidson', 'Aprilia', 'BMW', 'Benelli', 'Yo Style', 'Hyosung']
motorcycles = motorcycles[~motorcycles['make'].isin(makes_to_drop)]
motorcycles['make'].value_counts()
# Out:
# make
# Honda            292
# Bajaj            260
# Hero             144
# Royal Enfield    109
# Yamaha           102
# TVS               69
# Suzuki            30
# KTM               24
# Name: count, dtype: int64

# %%
# Pairplot with hue as make
sns.pairplot(motorcycles, hue='make')

# %% [markdown]
# ## The selling price of Royal Enfield motorcycles is slightly higher than the rest.

# %%
# Remove outliers
motorcycles = motorcycles[motorcycles['ex_showroom_price'] < 300000]

# %%
# Create a scatter plot with hue and regression lines
plt.figure(figsize=(20, 15))
sns.lmplot(x='selling_price', y='ex_showroom_price', hue='make', data=motorcycles, height=6, aspect=1.5)
plt.xlabel('Selling Price')
plt.ylabel('Showroom Price')

# Show plot
plt.show()

# %% [markdown]
# ## Honda's showroom price increases the most with the selling price. The Royal Enfield motorcycles' showroom price doesn't increase by much with the selling price.

# %%
counts = motorcycles['make'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
counts.plot(kind='bar', color='blue')

plt.title('Counts of Motorcycles by Make')
# Out:
# Text(0.5, 1.0, 'Counts of Motorcycles by Make')

# %% [markdown]
# ## Honda, Bajaj, Hero, and Yamaha are the most popular motorcycles.

# %%
# Create two subplots
fig, axes = plt.subplots(2, 1, figsize=(16, 20))

# KDE plot for selling price with hue
sns.kdeplot(data=motorcycles, x='selling_price', hue='make', shade=True, ax=axes[0])
axes[0].set_title('Kernel Density Estimate (KDE) Plot of Selling Price')
axes[0].set_xlabel('Selling Price')
axes[0].set_ylabel('Density')
axes[0].set_xlim(0, 250000)

# KDE plot for ex showroom price with hue
sns.kdeplot(data=motorcycles, x='ex_showroom_price', hue='make', shade=True, ax=axes[1])
axes[1].set_title('Kernel Density Estimate (KDE) Plot of Ex Showroom Price')
axes[1].set_xlabel('Ex Showroom Price')
axes[1].set_ylabel('Density')
axes[1].set_xlim(0, 250000)


plt.tight_layout()
plt.show()
# Out:
# C:\Users\marc\AppData\Local\Temp\ipykernel_12092\3363268522.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=motorcycles, x='selling_price', hue='make', shade=True, ax=axes[0])
# C:\Users\marc\AppData\Local\Temp\ipykernel_12092\3363268522.py:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=motorcycles, x='ex_showroom_price', hue='make', shade=True, ax=axes[1])

# %% [markdown]
# ## Royal Enfield motorcycles are in a much higher price range and there aren't that many of them. It is hard to see how much more the showroom price is than the selling price so let's calculate the price differences for each make.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the price difference
motorcycles['price_difference'] = motorcycles['ex_showroom_price'] - motorcycles['selling_price']

# Create a boxplot of the price difference with hue
plt.figure(figsize=(10, 8))
sns.boxplot(x='make', y='price_difference', data=motorcycles, palette='viridis')
plt.title('Boxplot of Price Difference (Showroom Price - Selling Price) with Hue')
plt.xlabel('Motorcycle Make')
plt.ylabel('Price Difference')
plt.grid(True)
plt.show()
# Out:
# C:\Users\marc\AppData\Local\Temp\ipykernel_12092\1813861111.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   motorcycles['price_difference'] = motorcycles['ex_showroom_price'] - motorcycles['selling_price']
# C:\Users\marc\AppData\Local\Temp\ipykernel_12092\1813861111.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='make', y='price_difference', data=motorcycles, palette='viridis')

# %% [markdown]
# ## KTM, with the least bikes in the set have the biggest price difference betweent the selling price and the ex showroom price. Honda has many outliers in the higher price difference. Interestingly Yamaha and Honda have outliers in the negative price difference, meaning that some motorcycles had a lower ex showroom price than a selling price.

# %% [markdown]
# ## Next let's look at how km_driven affects the selling price

# %%
# Create line plot of km_driven vs. selling_price with hue = make
plt.figure(figsize=(20, 16))
sns.lmplot(data=motorcycles, x='km_driven', y='selling_price', hue='make', palette='Set1', height=6, aspect=2)
plt.title('Line Plot of km_driven vs. Selling Price with Hue')
plt.xlabel('Kilometers Driven')
plt.ylabel('Selling Price')
plt.grid(True)
plt.xlim(0, 150000)
plt.ylim(0, 200000)
plt.show()

# %% [markdown]
# ## All motorcycles' prices decrease as the distance driven increases. Royal enfield's prices are the most affected by the distance driven. Royal Enfield motorcycles are also have the lowes mileage. Motorcycles that have the highest mileage are from Honda, Hero, Suzuki, and Yamaha. Honda's and Hero's selling prices are not affected much by the distance driven.

# %% [markdown]
# <h3><b>Ideas for further improvements:</b></h3>

# %% [markdown]
# ## Similar data for the same makes in another country would be very interesting. That way we could also compare what makes of motorcycles are popular in each country and see how the price differences between the selling price and the ex showroom price varies from country to country.
