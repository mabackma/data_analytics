# %% [markdown]
# <h3><b>Introduction to Data Analytics - Exercise set 3 - seaborn-module and data exploration</b></h3>

# %% [markdown]
# Put all your exercises (Jupyter Notebook/Python-files) in your course Git-project.
# Use either code comments or Jupyter Notebook markdown (text) to document which exercise you are doing and what a certain code section does!

# %% [markdown]
# <h3 style="color: red;">NOTE! Answer the questions within the exercises either as code comments or markdown text.</h3>

# %% [markdown]
# <h4><b>1. In this exercise, use the 'penguins' dataset from seaborn! </b></h4>
# <b>-> sns.load_dataset('penguins')
# </b>

# %%
# you can import numpy and pandas here
# and also load the needed dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_penguins = sns.load_dataset('penguins')
df_penguins
# Out:
# C:\Users\marc\AppData\Local\Temp\ipykernel_25096\210952869.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# <ul>
# <li>Create a pair plot of the data</li>
# <ul>
#     <li style="color: red; font-weight: bold;">What correlations can you immediately see?</li>
#     <li><b>Bonus extra task:</b> check out the correlation matrix for this dataset too</li>
# </ul>
# </ul>

# %%
# code here
sns.pairplot(df_penguins)

# %% [markdown]
# <p style="color: lightgreen;">There is a positive correllation between flipper length and body mass because the scatter plot is from the bottom left to the top right.</p>

# %%
print("Correlation matrix: ")

# Select only the numeric columns
df_penguins.select_dtypes(include=['float64', 'int64']).corr()
# Out:
# Correlation matrix:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %% [markdown]
# <li>Use hue for the "island" column, <span style="color: red; font-weight: bold;">what can you see in the data this way?</span></li>

# %%
# code here
sns.pairplot(df_penguins, hue='island')

# %% [markdown]
# <p style="color: lightgreen;">The penguins in Biscoe island are bigger than the penguins in Torgersen and Dream islands.<p/>

# %% [markdown]
# <ul>
#     <li>Find the amount of penguins on each island by using pandas (<b>value_counts()</b>). <span style="color: red; font-weight: bold;">Which island is different compared to others?</span></li>
#     <ul>
#         <li><b>Small extra task:</b> visualize the counts with a bar plot</li>
#     </ul>
# </ul>

# %%
# code here
penguins_per_island = df_penguins['island'].value_counts()
penguins_per_island.plot(kind='bar', title='Penguins per island')
# Out:
# <Axes: title={'center': 'Penguins per island'}, xlabel='island'>

# %% [markdown]
# <ul>
#     <li>Create now another pair plot, and use hue for the "species" –column</li>
#     <ul>
#         <li style="color: red; font-weight: bold;">Is there a difference in the distributions when using hue for the islands instead?</li>
#         <li><b>Bonus task:</b> <span style="color: red; font-weight: bold;">How much does the "sex"-column affect the result?</span> (MALE / FEMALE)</li>
#     </ul>
# </ul>

# %%
# code here
sns.pairplot(df_penguins, hue='species')

# %% [markdown]
# <p style="color: lightgreen;">The scatter plots look similar when using species and islands as the hue. We can assume that one island has only one species of penguins.</p>

# %%
sns.pairplot(df_penguins, hue='sex')

# %% [markdown]
# <p style="color: lightgreen;">Male penguins are larger than female penguins</p>

# %% [markdown]
# <ul>
#     <li>Create a scatter plot for <b><i>bill_length_mm</i></b> and <b><i>flipper_length_mm</i></b>, use species as hue (try also island as hue)</li>
#     <ul>
#         <li style="color: red; font-weight: bold;">Which affects the result more, species or island?</li>
#     </ul>
# </ul>

# %%
# code here
sns.scatterplot(data=df_penguins, x='bill_length_mm', y='flipper_length_mm', hue='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.scatterplot(data=df_penguins, x='bill_length_mm', y='flipper_length_mm', hue='island')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# <p style="color: lightgreen;">Species affects the result more, revealing well defined groups of data.</p>

# %% [markdown]
# <ul>
#     <li>Use box plots, violin plots or swarm plots:</li>
#     <ul>
#         <li>inspect the following information:</li>
#         <ul>
#             <li><b></i>flipper_length_mm</i></b></li>
#             <li><b></i>bill_length_mm</i></b></li>
#             <li><b></i>body_mass_g</i></b></li>
#         </ul>
#         <li>hue = island,  x= species</li>
#         <ul>
#             <li style="color: red; font-weight: bold;">What interesting insights/findings can you see in the data this way? </li>
#             <li style="color: darkred; font-weight: bold;">Or in other words: "how the data works regarding the variables above?" </li>
#         </ul>
#     </ul>
# </ul>

# %%
# code here
sns.boxplot(x='body_mass_g', y='flipper_length_mm', data=df_penguins)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# <p style="color: lightgreen;">The flipper length increases with body mass</p>

# %%
sns.violinplot(x='body_mass_g', y='bill_length_mm', data=df_penguins)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='bill_length_mm'>

# %% [markdown]
# <p style="color: lightgreen;">The bill length increases with body mass</p>

# %%
sns.swarmplot(x='bill_length_mm', y='flipper_length_mm', data=df_penguins, hue='species')
# Out:
# c:\Users\marc\Documents\TIEDOSTOT\LAPIN AMK 2024\DATA_ANALYTICS\data_analytics\.venv\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\marc\Documents\TIEDOSTOT\LAPIN AMK 2024\DATA_ANALYTICS\data_analytics\.venv\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\marc\Documents\TIEDOSTOT\LAPIN AMK 2024\DATA_ANALYTICS\data_analytics\.venv\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\marc\Documents\TIEDOSTOT\LAPIN AMK 2024\DATA_ANALYTICS\data_analytics\.venv\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\marc\Documents\TIEDOSTOT\LAPIN AMK 2024\DATA_ANALYTICS\data_analytics\.venv\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\marc\Documents\TIEDOSTOT\LAPIN AMK 2024\DATA_ANALYTICS\data_analytics\.venv\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 28.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\marc\Documents\TIEDOSTOT\LAPIN AMK 2024\DATA_ANALYTICS\data_analytics\.venv\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\marc\Documents\TIEDOSTOT\LAPIN AMK 2024\DATA_ANALYTICS\data_analytics\.venv\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# <p style="color: lightgreen;">Bill length increases as flipper length increses. Gentoo penguin's flippers are the largest.</p>

# %% [markdown]
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_3/penguins.png" />

# %% [markdown]
# <h4><b>2. In this exercise, use the 'mpg' dataset from seaborn! </b></h4>
# <b>-> sns.load_dataset('mpg')</b>
# <p>
# mpg stands for "miles per gallon", which is a common way to represent fuel consumption in USA.
# </p>

# %% [markdown]
# <b>Clean up the data (instructions and tasks below)</b>

# %% [markdown]
# <ul>
# <li>Create a new column: <b>"liters_per_100km"</b> , which converts the mpg to liters per 100 km</li>
# <ul>
# <li>You can Google the conversion formula easily: "miles per gallon to liters per 100km" or "How do you convert MPG to l 100km?"
# </li>
# <li>remove the original mpg –column after this</li>
# </ul>
#
# </ul>

# %%
# code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_mpg = sns.load_dataset('mpg')
df_mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# <li>Remove the "name" -column</li>

# %%
# code here
df_mpg = df_mpg.drop('name', axis=1)
df_mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70     usa
# 1            70     usa
# 2            70     usa
# 3            70     usa
# 4            70     usa
# ..          ...     ...
# 393          82     usa
# 394          82  europe
# 395          82     usa
# 396          82     usa
# 397          82     usa
#
# [398 rows x 8 columns]

# %% [markdown]
# <ul>
# <li>After this, create a correlation matrix. There are two
# columns that do not correlate as much as the others,
# remove these two from the dataset <span style="color: red; font-weight: bold;">(mention also which columns you decided to remove and why)</span></li>
# <ul>
# <li style="font-weight: bold;">Create also a heatmap of the correlation matrix after you remove the two unneeded columns</li>
# </ul>
# </ul>

# %%
# code here
df_mpg = df_mpg.drop('acceleration', axis=1)
df_mpg = df_mpg.drop('model_year', axis=1)
correlation_matrix = df_mpg.corr(numeric_only=True)
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %% [markdown]
# <p style="color: lightgreen;">acceleration and model_year had values closest to 0 in the correlation matrix so I removed them from the dataset</p>

# %% [markdown]
# <ul>
# <li>There are three different columns that are strongly
# connected to the car's efficiency (both power and
# consumption), select one of them and remove the others
# from the dataset
# </li>
# <ul>
# <li style="color: red; font-weight: bold;">Which column is the best selection to indicate the
# car’s efficiency, and why? (cylinders, horsepower or
# displacement/engine size)</li>
# <li style="color: darkred; font-weight: bold;">Remember: look at the big picture, also compare how well the variables correlate to other variables than just the consumption</li>
# </ul>
# </ul>

# %%
# out of the three, displacement shows the highest correlation with mpg
# displacement also has a high correlation with horsepower and cylinders
df_mpg = df_mpg.drop('cylinders', axis=1)
df_mpg = df_mpg.drop('horsepower', axis=1)
df_mpg
# Out:
#       mpg  displacement  weight  origin
# 0    18.0         307.0    3504     usa
# 1    15.0         350.0    3693     usa
# 2    18.0         318.0    3436     usa
# 3    16.0         304.0    3433     usa
# 4    17.0         302.0    3449     usa
# ..    ...           ...     ...     ...
# 393  27.0         140.0    2790     usa
# 394  44.0          97.0    2130  europe
# 395  32.0         135.0    2295     usa
# 396  28.0         120.0    2625     usa
# 397  31.0         119.0    2720     usa
#
# [398 rows x 4 columns]

# %% [markdown]
# <ul>
#     <li><b>Finally, use the pair plot and hue (origin)</b></li>
#     <ul>
#         <li style="color: red; font-weight: bold;">Which origin country tends have bigger fuel consumption in
# cars?</li>
# <li><span style="color: red; font-weight: bold;">Which is generally the origin with lowest consumption?</span>
# (more specific plots might be a good idea here, for example:
# box plot, scatter plot etc., pandas functions are helpful too!)</li>
# <li style="color: red; font-weight: bold;">What other features the cars seem to have that result into
# bigger or lower consumption?</li>
#     </ul>
# </ul>

# %%
# code here
sns.pairplot(df_mpg, hue='origin')

# %% [markdown]
# <p style="color: lightgreen;">Some Japanese and European cars have higher miles per gallon values than American cars at a low displacement values. Therefore Japanese and European cars have better fuel consumption than American cars. Fom looking at the displacement vs mpg scatterplot, we see that Japanese cars have the lowest consumption. From looking at the mpg vs weight scatterplot, we see that heavier cars use more fuel.</p>

# %% [markdown]
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_3/mpg.png" />

# %% [markdown]
# <h4><b>3. csv-data, pandas and seaborn, groceries data</b></h4>

# %% [markdown]
# <p>
# This dataset has been downloaded from <b><i>kaggle.com</i></b>.<br />
# Download the "groceries.csv" from Moodle.
# <br /><br />
# Load the data by using pandas. (read_csv() etc.)
# <br /><br />
#
# <b>Note:</b> since this is an actual dataset from the internet, the data is in quite a rough format.
#
# </p>

# %% [markdown]
# <li>If you take a look at the data, you will notice three columns have NaN –
# values. You can either remove these columns all together, or you can fill
# the missing values with average values of that column. For example, for
# the Fish -column you could do something like this:<br /><br />
#
# <b>df['Fish'].fillna((df['Fish'].mean()), inplace=True)</b><br /><br />
# In this case, food is the name of the DataFrame we just got from the csv-file. Do this same operation to the two other columns with missing
# values.</li>

# %%
# handle incomplete rows here, justify your approach on how you handled them
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_groceries = pd.read_csv('groceries.csv')
df_groceries['Fish'].fillna((df_groceries['Fish'].mean()), inplace=True)
df_groceries['Pork'].fillna((df_groceries['Pork'].mean()), inplace=True)
df_groceries['Sunflower-oil'].fillna((df_groceries['Sunflower-oil'].mean()), inplace=True)
df_groceries
# Out:
# C:\Users\marc\AppData\Local\Temp\ipykernel_20496\3835484050.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# C:\Users\marc\AppData\Local\Temp\ipykernel_20496\3835484050.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_groceries['Fish'].fillna((df_groceries['Fish'].mean()), inplace=True)
# C:\Users\marc\AppData\Local\Temp\ipykernel_20496\3835484050.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_groceries['Pork'].fillna((df_groceries['Pork'].mean()), inplace=True)
# C:\Users\marc\AppData\Local\Temp\ipykernel_20496\3835484050.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_groceries['Sunflower-oil'].fillna((df_groceries['Sunflower-oil'].mean()), inplace=True)
#       Month  Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  \
# 0    Oct-90  0.28   0.11    0.09  0.10     2.12  0.0049         0.28
# 1    Nov-90  0.27   0.11    0.09  0.10     2.11  0.0049         0.34
# 2    Dec-90  0.26   0.11    0.09  0.10     2.00  0.0046         0.32
# 3    Jan-91  0.30   0.11    0.09  0.11     1.85  0.0042         0.34
# 4    Feb-91  0.33   0.11    0.09  0.11     1.79  0.0042         0.33
# ..      ...   ...    ...     ...   ...      ...     ...          ...
# 355  May-20  0.51   0.21    0.08  0.14     2.05  0.0053         0.83
# 356  Jun-20  0.52   0.20    0.08  0.15     2.05  0.0060         0.92
# 357  Jul-20  0.48   0.20    0.08  0.15     1.99  0.0060         0.89
# 358  Aug-20  0.50   0.20    0.08  0.15     1.30  0.0064         0.98
# 359  Sep-20  0.51   0.20    0.08  0.17     1.68  0.0062         1.03
#
#      Palm-oil  Sunflower-oil  Chicken    Beef      Pork      Fish   Tea  \
# 0        0.29       0.580000   0.0236  0.0571  2.505100  6.350000  1.60
# 1        0.33       0.560000   0.0236  0.0558  2.441400  6.460000  1.58
# 2        0.35       0.550000   0.0231  0.0562  2.347900  6.500000  1.52
# 3        0.35       0.570000   0.0231  0.0571  2.649500  6.340000  1.55
# 4        0.34       0.600000   0.0238  0.0602  2.351700  6.410000  1.48
# ..        ...            ...      ...     ...       ...       ...   ...
# 355      0.58       0.914201   0.0335  0.1120  1.500345  4.806947  1.97
# 356      0.66       0.914201   0.0346  0.1124  1.500345  4.806947  1.86
# 357      0.69       0.914201   0.0335  0.1036  1.500345  4.806947  1.78
# 358      0.76       0.914201   0.0331  0.1021  1.500345  4.806947  2.00
# 359      0.80       0.914201   0.0324  0.1014  1.500345  4.806947  2.05
#
#      Coffee
# 0      1.24
# 1      1.22
# 2      1.24
# 3      1.16
# 4      1.14
# ..      ...
# 355    1.42
# 356    1.42
# 357    1.49
# 358    1.60
# 359    1.60
#
# [360 rows x 16 columns]

# %% [markdown]
# <ul>
# <li>In this data, the date column is a bit difficult to use, since it's not
# completely in numerical format. Split the Month-column so, that you
# have two different columns: Month and Year</li>
# <ul>
# <li>For month, use a numeric format 1-12</li>
# <li>For year, use the full year 1990-2020</li>
# <li>Check out the examples in Moodle, this one is a bit tricky, but
# very neat to know how it's done!</li>
# </ul>
# </ul>

# %%
# code here
import calendar

def change_month(row):
    return list(calendar.month_abbr).index(row['Month'])

def fix_year(row):
    year = int(row['Year'])
    if year > 50:
        return int(f"19{row['Year']}")
    else:
        if year < 10:
            return int(f"200{row['Year']}")
        else:
            return int(f"20{row['Year']}")

df_temp = pd.DataFrame()
df_temp['Month'] = df_groceries['Month'].str.split('-', expand=True)[0]
df_temp['Year'] = df_groceries['Month'].str.split('-', expand=True)[1]
df_groceries['Month'] = df_temp['Month']
df_groceries['Year'] = df_temp['Year']

# fix the year column
df_groceries['Year'] = df_groceries['Year'].astype(int)
df_groceries['Year'] = df_groceries.apply(fix_year, axis=1)

# fix the month column    
df_groceries['Month'] = df_groceries.apply(change_month, axis=1)

df_groceries
# Out:
#      Month  Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  Palm-oil  \
# 0       10  0.28   0.11    0.09  0.10     2.12  0.0049         0.28      0.29
# 1       11  0.27   0.11    0.09  0.10     2.11  0.0049         0.34      0.33
# 2       12  0.26   0.11    0.09  0.10     2.00  0.0046         0.32      0.35
# 3        1  0.30   0.11    0.09  0.11     1.85  0.0042         0.34      0.35
# 4        2  0.33   0.11    0.09  0.11     1.79  0.0042         0.33      0.34
# ..     ...   ...    ...     ...   ...      ...     ...          ...       ...
# 355      5  0.51   0.21    0.08  0.14     2.05  0.0053         0.83      0.58
# 356      6  0.52   0.20    0.08  0.15     2.05  0.0060         0.92      0.66
# 357      7  0.48   0.20    0.08  0.15     1.99  0.0060         0.89      0.69
# 358      8  0.50   0.20    0.08  0.15     1.30  0.0064         0.98      0.76
# 359      9  0.51   0.20    0.08  0.17     1.68  0.0062         1.03      0.80
#
#      Sunflower-oil  Chicken    Beef      Pork      Fish   Tea  Coffee  Year
# 0         0.580000   0.0236  0.0571  2.505100  6.350000  1.60    1.24  1990
# 1         0.560000   0.0236  0.0558  2.441400  6.460000  1.58    1.22  1990
# 2         0.550000   0.0231  0.0562  2.347900  6.500000  1.52    1.24  1990
# 3         0.570000   0.0231  0.0571  2.649500  6.340000  1.55    1.16  1991
# 4         0.600000   0.0238  0.0602  2.351700  6.410000  1.48    1.14  1991
# ..             ...      ...     ...       ...       ...   ...     ...   ...
# 355       0.914201   0.0335  0.1120  1.500345  4.806947  1.97    1.42  2020
# 356       0.914201   0.0346  0.1124  1.500345  4.806947  1.86    1.42  2020
# 357       0.914201   0.0335  0.1036  1.500345  4.806947  1.78    1.49  2020
# 358       0.914201   0.0331  0.1021  1.500345  4.806947  2.00    1.60  2020
# 359       0.914201   0.0324  0.1014  1.500345  4.806947  2.05    1.60  2020
#
# [360 rows x 17 columns]

# %% [markdown]
# <li>After the cleanups, create a correlation matrix of the data. Create a heatmap on the correlations as well.
# <br /><br />
# <span style="color: red; font-weight: bold;">Which grocery stands out?</span> (i.e. there seems to be one grocery item
# whose price doesn't follow other groceries at all)
# </li>

# %%
# code here
groceries_corr = df_groceries.corr()
sns.heatmap(groceries_corr, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# <li style="color: red; font-weight: bold;">Which groceries seem to correlate to each other's prices? What do they have in common?</li>

# %% [markdown]
# <p style="color: lightgreen;">Sunflower-oil stands out and has the lowest correllations with the other products. Corn, barley, and wheat correllate with each other. They are all cultivated crops.</p>

# %%
# code here
pivot_groceries = df_groceries.pivot_table(index='Month', columns='Year', values='Corn')
sns.heatmap(pivot_groceries, cmap='PiYG')
# Out:
# <Axes: xlabel='Year', ylabel='Month'>

# %% [markdown]
# <p style="color: lightgreen;">Corn was expensive in July-August 2012. "In the summer of 2012, weather conditions caused the most severe drought the United States has seen since the 1950s". Also barley was expensive during this time.</p><a href="https://www.bls.gov/opub/ted/2012/ted_20121128.htm#:~:text=In%20the%20summer%20of%202012,the%2020%2Dyear%20historical%20average.">TED: The Economics Daily</a>

# %% [markdown]
# <b>Bonus task:</b>
# <p>Sometimes data can also reflect history! For example, "Corn" and some
# other foods seem to have a notable peak in its price in one of the years.
# Find this year, and Google if you can find a reason for the price peak (for
# example, search: "us corn expensive XXXX". <span style="color: red; font-weight: bold;">Can you find any other food
# that has relation to a real world event in a similar in this dataset?</span></p>
# <p><b>Tip:</b> use pivot table and heatmap! Remember also, the first year in the
# dataset might show as blank white, that means there's no data. You
# should also split the date</p>
# <br />
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_3/food.png" />

# %%
pivot_groceries = df_groceries.pivot_table(index='Month', columns='Year', values='Wheat')
sns.heatmap(pivot_groceries, cmap='PiYG')
# Out:
# <Axes: xlabel='Year', ylabel='Month'>

# %%
pivot_groceries = df_groceries.pivot_table(index='Month', columns='Year', values='Barley')
sns.heatmap(pivot_groceries, cmap='PiYG')
# Out:
# <Axes: xlabel='Year', ylabel='Month'>

# %% [markdown]
# <p style="color: lightgreen;">Corn, wheat and barley were priced high in 2008 and 2012. In 2008 "root causes may be the increasing use of biofuels in developed countries (see also food vs fuel), and an increasing demand for a more varied diet across the expanding middle-class populations of Asia"</p>
#
# <a href="https://en.wikipedia.org/wiki/2007%E2%80%932008_world_food_price_crisis#:~:text=Root%20causes%20may%20be%20the,to%20major%20shifts%20in%20prices."> 2007-2008 world food price crisis</a>

# %% [markdown]
# <h4><b>4. csv-data, pandas and seaborn, mobile phone data, regression plots</b></h4>

# %% [markdown]
# <p>This dataset has been downloaded from <b><i>kaggle.com</i></b> and modified. <br />
# Download the "mobilephones.csv" from Moodle.  Load the data by using pandas.  (read_csv() etc.)</p>
#
# <p>
# Regression plots (<b>lmplot()</b> in seaborn) are often extremely useful in finding more insight and "hidden connections" in your data. </p>
#
# <p>
# Remember to also check out the confidence interval, if it's wide around the regression line = there's usually fluctuation within the values. <br />Narrow line => the linear connection is quite evident.</p>

# %% [markdown]
# <b>With the mobile phone data, do the following:</b>

# %% [markdown]
# <ul>
#
# <li>Use regression plot for RAM and Price, no hue</li>
# <ul>
#     <li style="color: red; font-weight: bold;">What is the correlation based on the regression line?</li>
# </ul>
#
#
#
# </ul>

# %%
# code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_mobilephones = pd.read_csv('mobilephones.csv')
sns.lmplot(x='RAM', y='Price', data=df_mobilephones)
# Out:
# C:\Users\marc\AppData\Local\Temp\ipykernel_38160\3504776957.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# <p style="color: lightgreen;">Phones with more RAM cost more</p>

# %% [markdown]
# <ul>
# <li>Use regression plot for RAM and Price, hue on Brand</li>
# <ul>
#     <li style="color: red; font-weight: bold;">How is the correlation different when compared to without hue?</li>
# </ul>
# </ul>

# %%
# code here
sns.lmplot(x='RAM', y='Price', data=df_mobilephones, hue='Brand')

# %% [markdown]
# <p style="color: lightgreen;">Adding hue on Brand shows the regression plots for each brand.</p>

# %% [markdown]
# <ul>
# <li>Use regression plot for BatteryCapacity and Price, no hue</li>
# <ul>
#     <li style="color: red; font-weight: bold;">What is the correlation based on the regression line?</li>
# </ul>
#
#
# </ul>

# %%
# code here
sns.lmplot(x='BatteryCapacity', y='Price', data=df_mobilephones)

# %% [markdown]
# <p style="color: lightgreen;">The regression line falsely shows that all phones with more battery capacity are cheaper.</p>

# %% [markdown]
# <ul>
# <li>Use regression plot for BatteryCapacity and Price, hue on Brand</li>
# <ul>
#     <li style="color: red; font-weight: bold;">How is the correlation different when compared to without hue?</li>
# </ul>
# </ul>

# %%
# code here
sns.lmplot(x='BatteryCapacity', y='Price', data=df_mobilephones, hue='Brand')

# %% [markdown]
# <p style="color: lightgreen;">After adding hue on Brand we see that as the battery capacity increases, Apple and Asus prices increase while Xiaomi prices decrease. Samsung prices don't follow a trend.</p>

# %% [markdown]
# <ul>
# <li><b>Bonus task:</b> Use regression plot for ScreenSize and Price, without and with hue on Brand</li>
# <ul>
#     <li style="color: red; font-weight: bold;">Compare the correlations with and without hue. Is there a difference?</li>
# </ul>
# </ul>

# %%
# optional bonus task code here
sns.lmplot(x='ScreenSize', y='Price', data=df_mobilephones, hue='Brand')

# %% [markdown]
# <p style="color: lightgreen;">Adding hue on Brand to the regression plot for ScreenSize and Price, reveals that all phones, except for Blackberry, increase in price as their screen size gets bigger.</p>

# %% [markdown]
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_3/mobilephone.png" />

# %% [markdown]
# <h2><b>Advanced extra tasks for extra points (varying challenges, some require Googling):</b></h2>

# %% [markdown]
# <ul>
# <li>1. <b>seaborn:</b> Try out Boxenplot and/or Dendrogram in any of the previous
# dataset exercises. Do these plot types provide some interesting info on
# the data? (Google for examples on these plot types)</li>
# <ul>
# <li>You may also consider some other plots, for example:
# <b>displot, catplot, relplot</b></li>
# </ul>
# </ul>

# %%
# code for the advanced extra task
sns.boxenplot(data=df_mobilephones, x='RAM', y='Price', hue='Brand', width=1)
# Out:
# <Axes: xlabel='RAM', ylabel='Price'>

# %% [markdown]
# <p style="color: lightgreen;">Samsung phones with higher RAM have a wider price range.</p>
